# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
movies_data = pd.read_csv('/content/movies.csv')

# %%
movies_data.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
movies_data.shape
# Out:
# (4803, 24)

# %%
selecting_features=['genres','title','cast','director']

# %%
print(selecting_features)
# Out:
# ['genres', 'title', 'cast', 'director']

# %%
for feature in selecting_features:
  movies_data[feature]=movies_data[feature].fillna('')

# %%
combine_feature=movies_data['genres']+' '+movies_data['title']+' '+movies_data['cast']+' '+movies_data['director']

# %%
print(combine_feature)
# Out:
# 0       Action Adventure Fantasy Science Fiction Avata...
# 1       Adventure Fantasy Action Pirates of the Caribb...
# 2       Action Adventure Crime Spectre Daniel Craig Ch...
# 3       Action Crime Drama Thriller The Dark Knight Ri...
# 4       Action Adventure Science Fiction John Carter T...
#                               ...
# 4798    Action Crime Thriller El Mariachi Carlos Galla...
# 4799    Comedy Romance Newlyweds Edward Burns Kerry Bi...
# 4800    Comedy Drama Romance TV Movie Signed, Sealed, ...
# 4801     Shanghai Calling Daniel Henney Eliza Coupe Bi...
# 4802    Documentary My Date with Drew Drew Barrymore B...
# Length: 4803, dtype: object

# %%
vectorizer=TfidfVectorizer()

# %%
feature_vector=vectorizer.fit_transform(combine_feature)

# %%
print(feature_vector)
# Out:
#   (0, 2118)	0.2309975990859801
#   (0, 6606)	0.1516184068176798
#   (0, 11182)	0.2597674218135412
#   (0, 8893)	0.2147654852702227
#   (0, 7565)	0.30370560783956707
#   (0, 12554)	0.20297647787895115
#   (0, 14252)	0.26690381122258344
#   (0, 12103)	0.2754477868181338
#   (0, 11451)	0.2912103359691949
#   (0, 14804)	0.2684834146970968
#   (0, 14537)	0.3162008797099394
#   (0, 11478)	0.20055321875601223
#   (0, 866)	0.38152944129401706
#   (0, 4572)	0.1389325735892067
#   (0, 11688)	0.13909586065539098
#   (0, 4446)	0.1493850618191477
#   (0, 195)	0.12162130713420419
#   (0, 143)	0.10530574827228552
#   (1, 13974)	0.24782420663400193
#   (1, 5352)	0.24034892305845657
#   (1, 4475)	0.22460385496459934
#   (1, 14695)	0.2342411716538435
#   (1, 2563)	0.22907714142180124
#   (1, 13547)	0.21102081998444094
#   (1, 12181)	0.21244656222423522
#   :	:
#   (4801, 2972)	0.30996417313733493
#   (4801, 11324)	0.2956564726143287
#   (4801, 2102)	0.2956564726143287
# ...

# %%
similarity=cosine_similarity(feature_vector)

# %%
print(similarity)
# Out:
# [[1.         0.03717319 0.06196305 ... 0.         0.         0.        ]
#  [0.03717319 1.         0.0187114  ... 0.         0.         0.        ]
#  [0.06196305 0.0187114  1.         ... 0.         0.06765132 0.        ]
#  ...
#  [0.         0.         0.         ... 1.         0.         0.02653415]
#  [0.         0.         0.06765132 ... 0.         1.         0.        ]
#  [0.         0.         0.         ... 0.02653415 0.         1.        ]]

# %%
print(similarity.shape)
# Out:
# (4803, 4803)

# %%
movie_name=input('Enter your favourite movie name : ')
# Out:
# Enter your favourite movie name : iron man

# %%
list_titles=movies_data['title'].tolist()

# %%
print(list_titles)
# Out:
# ['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre', 'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'Superman Returns', 'Quantum of Solace', "Pirates of the Caribbean: Dead Man's Chest", 'The Lone Ranger', 'Man of Steel', 'The Chronicles of Narnia: Prince Caspian', 'The Avengers', 'Pirates of the Caribbean: On Stranger Tides', 'Men in Black 3', 'The Hobbit: The Battle of the Five Armies', 'The Amazing Spider-Man', 'Robin Hood', 'The Hobbit: The Desolation of Smaug', 'The Golden Compass', 'King Kong', 'Titanic', 'Captain America: Civil War', 'Battleship', 'Jurassic World', 'Skyfall', 'Spider-Man 2', 'Iron Man 3', 'Alice in Wonderland', 'X-Men: The Last Stand', 'Monsters University', 'Transformers: Revenge of the Fallen', 'Transformers: Age of Extinction', 'Oz: The Great and Powerful', 'The Amazing Spider-Man 2', 'TRON: Legacy', 'Cars 2', 'Green La
# ...

# %%
find_close_title=difflib.get_close_matches(movie_name,list_titles)

# %%
print(find_close_title)
# Out:
# ['Iron Man', 'Iron Man 3', 'Iron Man 2']

# %%
close_match=find_close_title[0]

# %%
index_of_movie=movies_data[movies_data.title == close_match]['index'].values[0]

# %%
similarity_score=list(enumerate(similarity[index_of_movie]))

# %%
sorted_similar_movies=sorted(similarity_score,key=lambda x:x[1],reverse=True)

# %%
print(sorted_similar_movies)
# Out:
# [(68, 1.0000000000000004), (79, 0.5908207289705288), (31, 0.4762622948376194), (3623, 0.22987407262515486), (2487, 0.20151046336961193), (2651, 0.19963284377026735), (16, 0.18596339877632204), (720, 0.182479661125318), (138, 0.18232485827086245), (26, 0.17070442980287615), (661, 0.1691226594470077), (7, 0.16762966710999408), (607, 0.16506704340461445), (977, 0.16414752533442237), (783, 0.16310258966028496), (3166, 0.16175513781151835), (954, 0.16072914244915115), (2880, 0.15906207190913635), (800, 0.15849846288212502), (1406, 0.15596912024181414), (1553, 0.15593795888453835), (789, 0.15461858206748436), (2235, 0.15340142831041859), (882, 0.15145302859153353), (2411, 0.1513382185372077), (198, 0.15130321846752112), (1380, 0.15124244798596953), (356, 0.15103212180195089), (2186, 0.1505420899161274), (3267, 0.14930959129662), (1664, 0.1486802708956316), (1180, 0.14550400634663416), (39, 0.14422544297015652), (1710, 0.14400527008042474), (2778, 0.1426852381482661), (1780, 0.1422945057559
# ...

# %%
print('Movies suggested for you : \n')
i=1
for movie in sorted_similar_movies:
  index=movie[0]
  title_from_index=movies_data[movies_data.index==index]['title'].values[0]
  if(i<20):
    print(i,'.',title_from_index)
    i+=1
# Out:
# Movies suggested for you :
#
# 1 . Iron Man
# 2 . Iron Man 2
# 3 . Iron Man 3
# 4 . Made
# 5 . Duets
# 6 . The Good Night
# 7 . The Avengers
# 8 . Contagion
# 9 . The Last Airbender
# 10 . Captain America: Civil War
# 11 . Zathura: A Space Adventure
# 12 . Avengers: Age of Ultron
# 13 . Sky Captain and the World of Tomorrow
# 14 . The Iron Giant
# 15 . Mortdecai
# 16 . The Best Man
# 17 . The Judge
# 18 . Charlie Bartlett
# 19 . Red Tails
